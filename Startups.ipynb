# 47     42559.73
# 44     65200.33
# Name: Profit, dtype: float64

# %%
x_test
# Out:
#     R&D Spend  Administration  Marketing Spend
# 28   66051.52       182645.56        118148.20
# 11  100671.96        91790.61        249744.55
# 10  101913.08       110594.11        229160.95
# 41   27892.92        84710.77        164470.71
# 2   153441.51       101145.55        407934.54
# 27   72107.60       127864.55        353183.81
# 38   20229.59        65947.93        185265.10
# 31   61136.38       152701.92         88218.23
# 22   73994.56       122782.75        303319.26
# 4   142107.34        91391.77        366168.42
# 33   55493.95       103057.49        214634.81
# 35   46014.02        85047.44        205517.64
# 26   75328.87       144135.98        134050.07
# 34   46426.07       157693.92        210797.67
# 18   91749.16       114175.79        294919.57

# %%
y_test
# Out:
# 28    103282.38
# 11    144259.40
# 10    146121.95
# 41     77798.83
# 2     191050.39
# 27    105008.31
# 38     81229.06
# 31     97483.56
# 22    110352.25
# 4     166187.94
# 33     96778.92
# 35     96479.51
# 26    105733.54
# 34     96712.80
# 18    124266.90
# Name: Profit, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
dt=DecisionTreeRegressor()
lr=LinearRegression()
lr.fit(x_train,y_train)
dt.fit(x_train,y_train)
rf.fit(x_train,y_train)
y_pred=lr.predict(x_test)
y_pred1=dt.predict(x_test)
y_pred2=rf.predict(x_test)
print(f"Linear Regression {y_pred}")
print(f"Decision Tree Regression {y_pred1}")
print(f" Random Forest Regression {y_pred2}")
# Out:
# Linear Regression [104054.44293869 132719.3459701  133640.26830949  72294.76911458
#  179685.62227843 114508.97572031  66305.23069863  98297.69326565
#  114277.91894933 169112.36095691  96257.40152149  87916.97242208
#  110687.33942598  90670.8337806  127780.63539583]
# Decision Tree Regression [101004.64 141585.52 141585.52  78239.91 182901.99 118474.03  71498.49
#   99937.59 118474.03 156991.12 107404.34 107404.34 126992.93 107404.34
#  125370.37]
#  Random Forest Regression [103027.4367 136743.8124 137001.3655  79509.7384 182726.161  118820.8927
#   72211.8396 100058.4326 116575.8131 169160.7334 102798.3464  89626.4519
#  115854.6427  90840.9359 128596.2948]

# %%
from sklearn.metrics import r2_score, accuracy_score,mean_absolute_error,mean_squared_error
l1=mean_absolute_error(y_test,y_pred)
l2=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print(l1)
print(l2)
print(r2)
l1=mean_absolute_error(y_test,y_pred1)
l2=mean_squared_error(y_test,y_pred1)
r2=r2_score(y_test,y_pred1)
print(l1)
print(l2)
print(r2)
l1=mean_absolute_error(y_test,y_pred2)
l2=mean_squared_error(y_test,y_pred2)
r2=r2_score(y_test,y_pred2)
print(l1)
print(l2)
print(r2)
# Out:
# 6489.6601704866425
# 62240269.842915125
# 0.9355188337118219
# 7710.073333333336
# 88788292.12588003
# 0.9080149773858361
# 6314.808740000014
# 51807272.6096235
# 0.9463274602036711
